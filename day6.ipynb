# %%
input = r'''...'''

# %%
from itertools import *
from more_itertools import *
import numpy as np
import networkx as nx
import regex as re
from sympy.ntheory import factorint
from collections import defaultdict
import copy as copy

# %%
def main(input):
  for position, window in enumerate(sliding_window(input, 4), start=4):
    if len(set(window)) == 4:
      return position

# %%
main(input)
# Out:
# 1896

# %%
def main(input):
  n = 14
  for position, window in enumerate(sliding_window(input, n), start=n):
    if len(set(window)) == n:
      return position

# %%
main(input)
# Out:
# 3452
